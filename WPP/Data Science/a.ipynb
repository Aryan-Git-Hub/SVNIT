# %%
import matplotlib.pyplot as plt
values = [1, 2, 3, 4, 5]
plt.hist(values, bins=2, color='skyblue', edgecolor='black', label='Frequency of Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Frequency of Values with 2 Bins')
plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
