# %% [markdown]
# # Python Core Data Type
# Python is purely object-oriented language.it referes to everythings as an object including
# numbers and strings. ## Integer

# %%
a =10
print('Decimal ',a)
print(type(a))
b = 0o10
print('Octal',b)
print(type(b))
c =0x10
print("Hexadical",c)
print(type(c))
# Out:
# Decimal  10
# <class 'int'>
# Octal 1
# <class 'int'>
# Hexadical 16
# <class 'int'>

# %% [markdown]
# # Note : Integer in Python 2.6 (int and long):
# 1. In Python 2.6 there are two types of integetes. One of 32 bits and another having unlimited precession. Python 2.6 automatically convert integers to long integers if the value of the integer overfloaws 32 bits
# 2. Integer in Python 3.0 (Only int type) - In Python 3.0 the normal int and long integer have been merged.there is only one type called intger

# %%
# int Function
# int function convert a String or number into a whole number to integer.
int(12.234)
age = int(input("Enter thw age of student"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # int Function
#       2 # int function convert a String or number into a whole number to integer.
#       3 int(12.234)
# ----> 4 age = int(input("Enter thw age of student"))
#
# File ~/Library/Python/3.12/lib/python/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/Library/Python/3.12/lib/python/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Floating Point
print(3.3e2) # Scientific Notation
print(3.7) # Decimal Notation
# Out:
# 0.033
# 3.7

# %%
#float funciton
float('14.55')
type(float('14.55'))

# %%
# Complex Number
#7.1 Complex number that can be expresses in the form a+bj, where a and b are real number and j is an imaginary unit.
a = 2 +4j
b = 3 + 5j
c = a+b
print(c)
print(type(c))
# Out:
# (5+9j)
# <class 'complex'>

# %%
#Boolean Type
#Boolean data type represent in Python as type bool
b=True
type(b)

# %%
#String type 
# A string literal or String in Python can be creted using single,double and triple quotes
str1='Praveen'
print(str1)
str2 = "Jain"
print(str2)
str3 = '''c
        cpp
        java

python''' # Triple single quotes are used to write a multiline
print(str3)
# Out:
# Praveen
# Jain
# c
#         cpp
#         java
#
# python

# %%
#str function
str(12.3)
# Out:
# '12.3'

# %%
# Escape Sequence
print("Hello World ,\" Hello world\"")
#Hello World ," Hello world"
print("Hello",end=" ")
print("Python",end=" ")
print("Python",end=" ")
# Out:
# Hello World ," Hello world"
# Hello Python Python

# %%
#Program to disaply data of different types using variables and literal constant.
roll_no =37
college = "SVNIT"
code=234
number_of_student=40000
name_of_student="Amit Kumar"
print("Roll_no ="+str(roll_no))
print("College="+str(college))
print("Code="+str(code))
print("Number of Studnet",str(number_of_student))
print("Name of Stundet",str(name_of_student))
# Out:
# Roll_no =37
# College=SVNIT
# Code=234
# Number of Studnet 40000
# Name of Stundet Amit Kumar

# %%
#Formatting Number and String
#format(item,format-specifier)
radius= int(input("Enter the radius of Circle"))
print("Radius ",radius)
PI =3.1428
area = PI * radius * radius
print(area)
print("Area of Circle",format(area,'10.2f')) # 3.2f ==> 3 =>Field Widht 2=>Precision 

print("Area of Circle: {:<10.2f}".format(area))

#Explanation:
#<: Left-aligns the content.
#6.2f: Reserves at least 6 spaces and formats the float to 2 decimal places. Adjust the width (e.g., 6) as needed.
# Out:
# Radius  6
# 113.1408
# Area of Circle                                             113.14
# Area of Circle: 113.14

# %%
#Integer Formatting
#• In case of integer formatting , you can make use of conversion code d (integer formatting) and x(hexadecimal integer).
print(format(20,"10x")) # Right formatted to Hexdecimal Integer
# Out:
#         14

# %%
print(format(20,"<10x"))
# Out:
# 14

# %%
# Formating with Float
float(16/(float(3))) # Without # Without using the formatting
# Out:
# '5.33'

# %%
format(float(16/float(3)),'.2f')
# Out:
# '5.33'

# %%
#Formatting String
print(format("Hello World!","50s")) # Left justify
print(format("Hello World!",">50s")) # Right Justify
# Out:
# Hello World!
#                                       Hello World!

# %%
#Formatting as a Percentage
print(format(0.31456,"10.3%")) # number multipled by 100
print(format(3.1,"10.2%")) # number multipled by 100
# Out:
#    31.456%
#    310.00%

# %%
#Multiple Assignment
sum = flag=a=b=0
print(sum)
print(flag)
print(a)
print(b)
sum,a,b,mesg=0,3,5,'Welcome in Python Course'
print(sum)
print(a)
print(b)
print(mesg)
# Out:
# 0
# 0
# 0
# 0
# 0
# 3
# 5
# Welcome in Python Course

# %%
# list Data type
list=[1,2,3,4,5]
print(list) # Mutable Data Type
print(list[1:2])
print(list[1:5:2])
print(list[::2])
print(list[-1])
list[1]=333
print(list)
# Out:
# [1, 2, 3, 4, 5]
# [2]
# [2, 4]
# [1, 3, 5]
# 5
# [1, 333, 3, 4, 5]

# %%
#Tuple Data Type
tuple=(1,2,3,3,4)
print(tuple) # Immutable Data Type
print(tuple[1])
print(tuple[1:3])
print(tuple[1:3:2])
print(tuple[:])
tuple[1]=333
print(tuple)
# Out:
# (1, 2, 3, 3, 4)
# 2
# (2, 3)
# (2,)
# (1, 2, 3, 3, 4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18336\3963274223.py in <module>
#       6 print(tuple[1:3:2])
#       7 print(tuple[:])
# ----> 8 tuple[1]=333
#       9 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Dictionary
dict1 ={'a':1,'b':3,'c':4,8:100}
print(dict1) # mutable data type
print(dict1['a'])
print(dict1.values())
print(list(dict1.items()))
# Out:
# {'a': 1, 'b': 3, 'c': 4, 8: 100}
# 1
# dict_values([1, 3, 4, 100])
# [('a', 1), ('b', 3), ('c', 4), (8, 100)]

# %%
#Set
set1 = set([1,2,3,3])
print(set1) # mutable data type
# Out:
# {1, 2, 3}
